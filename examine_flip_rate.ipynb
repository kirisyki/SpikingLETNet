# %%
import torch
import numpy as np

flip_rate_dict = torch.load('flip_rate_dict.pt', weights_only=False)

for key in flip_rate_dict:
    print(f"{key}: {flip_rate_dict[key][0] if isinstance(flip_rate_dict[key], torch.Tensor) else 'N/A'}")
# Out:
# layer_0: N/A
# layer_1: tensor([5.7450e-01, 3.1508e-01, 8.7170e-02, 2.0052e-02, 2.9505e-03, 2.4102e-04,
#         7.7148e-06, 1.9531e-06], device='cuda:3')
# layer_2: tensor([1., 0., 0., 0., 0., 0., 0., 0.], device='cuda:3')
# layer_3: tensor([0.8464, 0.1536, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:3')
# layer_4: N/A
# layer_5: tensor([1., 0., 0., 0., 0., 0., 0., 0.], device='cuda:3')
# layer_6: N/A
# layer_7: tensor([0.8539, 0.1422, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:3')
# layer_8: tensor([6.2006e-01, 3.7993e-01, 6.2500e-06, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00], device='cuda:3')
# layer_9: tensor([1., 0., 0., 0., 0., 0., 0., 0.], device='cuda:3')
# layer_10: tensor([6.2006e-01, 3.7993e-01, 6.2500e-06, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00], device='cuda:3')
# layer_11: tensor([4.8235e-01, 2.9247e-01, 2.2516e-01, 1.2500e-05, 0.0000e+00, 0.0000e+00,
# ...
