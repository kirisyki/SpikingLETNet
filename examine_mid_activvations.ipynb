# %%
import torch

mid_activations_dict = torch.load('mid_activations_dict.pth', weights_only=False)
for key, value in mid_activations_dict.items():
    print(f"{key}: {value[0].shape}, {value[1].shape}, {value[2]}")
# Out:
# layer_0: (1, 1, 3, 400, 400), (32, 3, 3, 3), Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
# layer_1: (1, 1, 32, 400, 400), (64, 32, 3, 3), Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
# layer_2: (1, 1, 64, 400, 400), (64, 64, 3, 3), Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, step_mode=m)
# layer_3: (1, 1, 64, 200, 200), (64, 64, 3, 3), Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), step_mode=m)
# layer_4: (1, 1, 64, 200, 200), (32, 64, 3, 3), Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, step_mode=m)
# layer_5: (1, 1, 96, 100, 100), (48, 96, 1, 1), Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False, step_mode=m)
# layer_6: (1, 1, 48, 100, 100), (48, 48, 3, 1), Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False, step_mode=m)
# ...
